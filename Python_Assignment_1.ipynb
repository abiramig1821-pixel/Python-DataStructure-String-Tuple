# %% [markdown]
# <a href="https://colab.research.google.com/github/abiramig1821-pixel/Python-DataStructure-String-Tuple/blob/main/Python_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="text-align: center; font-family: sans-serif; line-height: 1.8;">
#
# # **Data Analytics (DA)**
# ## **Python Assignment 1 - Data Structures - Strings & Tuples**
#
# </div>

# %% [markdown]
# ### **Problem Statement"**
#
# This assignment focuses on understanding Python string operations and tuple manipulation, including concatenation, slicing, built-in methods, and tuple operations.

# %% [markdown]
# ## **Tasks**
# ### **Strings (Concatenation, Slicing, and Other Methods):**
# 1.   String Concatenation:
# 2.   String Slicing and Indexing
# 3.   String Methods
#
# ### **Tuples (Creation, Modification and Access) :**
#
# 1.   Concatenate the two tuples and store it in “t_combine”
# 2.  Repeat the elements of “t_combine” 3 times
# 3.  Access the 3rd element from “t_combine”
# 4.  Access the first three elements from “t_combine”
# 5.  Access the last three elements from “t_combine”

# %% [markdown]
# ## **Strings (Concatenation, Slicing, and Other Methods):**
# ### 1.String Concatenation:
#
# Write a Python program that takes two strings, i.e., string 1 "Hello" and string 2 “get name” as input from the user, and concatenates them together. Display the concatenated string as the output.

# %%
# String 1 "Hello"
Str1 ="Hello"
Str1
# Out:
# 'Hello'

# %%
# String 2 "get name" as input from the user
Str2 = input("Enter Your Name:")
Str2
# Out:
# Enter Your Name:Harsha
# 'Harsha'

# %%
# Concatenate Str1 & Str2 and Str3

Str3 = "Welcome to Python Programming Language"
Str3
Welcome_Text = Str1 +" "+Str2+", "+ Str3
Welcome_Text
# Out:
# 'Hello Harsha, Welcome to Python Programming Language'

# %% [markdown]
# ## **2. String Slicing and Indexing:**
#
# Write a Python program using the above concatenated string as input and perform the following tasks:
#
# *   a. Print the first character of the string.
# *   b. Print the last character of the string.
# *   c. Print the first 5 characters of the string.
# *   d. Print the last 11 characters of the string.
# *   e. Print the string in reverse.
# *   f. Use slicing and print the word “Python” from the existing string.

# %%
# a. Print the first character of the string.

Welcome_Text[0]
# Out:
# 'H'

# %%
# b. Print the last character of the string.
Welcome_Text[-1]
# Out:
# 'e'

# %%
# c. Print the first 5 characters of the string.
Welcome_Text[0:6]
# Out:
# 'Hello '

# %%
# d. Print the last 11 characters of the string.

Welcome_Text[-11:]
# Out:
# 'ng Language'

# %%
 # e. Print the string in reverse.
 Welcome_Text[::-1]
# Out:
# 'egaugnaL gnimmargorP nohtyP ot emocleW ,ahsraH olleH'

# %% [markdown]
# ## **3.  String Methods:**
#
# Write a Python program that takes a string, strM = “Python beginner tutorial," and performs the following tasks:
#
#
# *   a. Convert the sentence to uppercase.
# *   b.  Convert the sentence to lowercase
# *   c.  Use Capitalize and return the sentence to the original input form.
# *   d.  Count the total number of occurrences of character ‘t’ in the string.
# *    e. Replace all occurrences of “Python” with “Data Analytics” in the input string strM = “Python beginner tutorial.”

# %%
# a. Convert the sentence to uppercase.

Welcome_Text.upper()
# Out:
# 'HELLO HARSHA, WELCOME TO PYTHON PROGRAMMING LANGUAGE'

# %%
# b. Convert the sentence to lowercase
Welcome_Text.lower()
# Out:
# 'hello harsha, welcome to python programming language'

# %%
# c. Use Capitalize and return the sentence to the original input form.
Welcome_Text.capitalize()
# Out:
# 'Hello harsha, welcome to python programming language'

# %%
# d. Count the total number of occurrences of character ‘t’ in the string.
Welcome_Text.count("t")
# Out:
# 2

# %%
# e. Replace all occurrences of “Python” with “Data Analytics” in the input string strM = “Python beginner tutorial.”

StrM = "Python beginner tutorial"
StrM
StrM1=StrM.replace("Python","Data Analytics")
StrM1
# Out:
# 'Data Analytics beginner tutorial'

# %% [markdown]
# ## **Tuples (Creation, Modification and Access) :**
#
# Create the 1st tuple with values -> (10, 20, 30) and the 2nd tuple with values -> (40, 50, 60):
#
# *   a. Concatenate the two tuples and store it in “t_combine”
# *   b.  Repeat the elements of “t_combine” 3 times
# *   c.  Access the 3rd element from “t_combine”
# *   d.  Access the first three elements from “t_combine”
# *   e.  Access the last three elements from “t_combine”

# %%
# Create Tuple 1 and Tuple 2

Tup1=(10,20,30)
Tup2=(40,50,60)
type(Tup1)
type(Tup2)
# Out:
# tuple

# %%
# a. Concatenate the two tuples and store it in “t_combine”
t_Combine = Tup1 + Tup2
t_Combine
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
# b. Repeat the elements of “t_combine” 3 times
t_Combine*3
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# d. Access the first three elements from “t_combine”
t_Combine[0:3]
# Out:
# (10, 20, 30)

# %%
# e.  Access the last three elements from “t_combine”
t_Combine[-3:]
# Out:
# (40, 50, 60)

# %% [markdown]
# ## **!!!!!!!!Thank You!!!!!!!!!!!!!!!**
